# %% [markdown]
# <h1><center>Bangalore House Price Prediction</center></h1>

# %% [markdown]
# # Step 1: Data Cleaning

# %%
#import necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (20,10)

# %%
pd.set_option('display.max_rows',300)
pd.set_option('display.max_columns',1400)

# %%
#load dataset

df1 = pd.read_csv('bengaluru_house_prices.csv')

# %%
df1.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df1.shape
# Out:
# (13320, 9)

# %%
#check percentage of NaN data in every column
round((100*df1.isnull().sum())/len(df1.index),2)
# Out:
# area_type        0.00
# availability     0.00
# location         0.01
# size             0.12
# society         41.31
# total_sqft       0.00
# bath             0.55
# balcony          4.57
# price            0.00
# dtype: float64

# %%
df1['area_type'].value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
#plot to show different Area Type and Price comparision

plt.yscale('log')
ax = sb.boxplot('area_type','price',data=df1)
ax.set_xlabel('Area Type',fontdict={'fontsize':16})
ax.set_ylabel('Price',fontdict={'fontsize':16})
ax.set_title('Area Type & Price',fontdict={'fontsize':17})
# Out:
# Text(0.5,1,'Area Type & Price')

# %% [markdown]
# ### We can see from the above plot that their is no relation between area type and price

# %%
#plot to show different numbers of balcony and Price comparision

plt.yscale('log')
ax = sb.boxplot('balcony','price',data=df1)
ax.set_xlabel('Balcony',fontdict={'fontsize':16})
ax.set_ylabel('Price',fontdict={'fontsize':16})
ax.set_title('Balcony & Price',fontdict={'fontsize':17})
# Out:
# Text(0.5,1,'Balcony & Price')

# %% [markdown]
# ### We can clearly see from the above plot that there is no relation between Balcony and Price

# %%
df1['availability'].value_counts()
# Out:
# Ready To Move           10581
# 18-Dec                    307
# 18-May                    295
# 18-Apr                    271
# 18-Aug                    200
# 19-Dec                    185
# 18-Jul                    143
# 18-Mar                    131
# 18-Jun                     99
# 20-Dec                     98
# 21-Dec                     93
# 19-Mar                     88
# 18-Feb                     62
# 18-Nov                     47
# 18-Jan                     43
# 18-Sep                     41
# 19-Jun                     40
# 19-Jan                     39
# 18-Oct                     39
# 19-Jul                     36
# 17-Dec                     29
# 20-Jan                     24
# 17-Oct                     21
# 19-Sep                     21
# 22-Jun                     19
# 19-Aug                     18
# 21-Jun                     17
# 19-Apr                     16
# Immediate Possession       16
# 20-Aug                     16
# 19-Oct                     15
# 21-Mar                     14
# 17-Jun                     13
# 21-Jan                     12
# 17-Jul                     12
# 21-May                     12
# 17-Nov                     12
# 17-Sep                     11
# 22-Dec                     11
# 20-Jun                     11
# 22-May                     10
# 17-Aug                      9
# 19-May                      9
# 21-Jul                      8
# 17-May                      8
# 19-Nov                      7
# 20-Oct                      7
# 17-Apr                      7
# 22-Jan                      6
# 21-Feb                      6
# 21-Sep                      6
# 21-Oct                      6
# 20-Sep                      6
# 21-Aug                      5
# 20-Jul                      5
# 17-Mar                      5
# 16-Dec                      4
# 20-Nov                      4
# 20-May                      4
# 20-Apr                      4
# 22-Mar                      3
# 19-Feb                      3
# 16-Mar                      3
# 21-Nov                      3
# 17-Feb                      2
# 20-Mar                      2
# 15-Oct                      2
# 15-Nov                      2
# 22-Nov                      2
# 16-Sep                      2
# 20-Feb                      2
# 14-Jul                      1
# 14-Nov                      1
# 16-Nov                      1
# 17-Jan                      1
# 15-Aug                      1
# 15-Jun                      1
# 15-Dec                      1
# 16-Jan                      1
# 16-Oct                      1
# 16-Jul                      1
# Name: availability, dtype: int64

# %%
df1.groupby('availability')['price'].mean()
# Out:
# availability
# 14-Jul                   43.710000
# 14-Nov                   43.710000
# 15-Aug                   62.000000
# 15-Dec                  130.000000
# 15-Jun                   97.000000
# 15-Nov                  125.000000
# 15-Oct                  280.500000
# 16-Dec                  130.000000
# 16-Jan                  110.000000
# 16-Jul                  129.000000
# 16-Mar                  150.333333
# 16-Nov                   39.000000
# 16-Oct                   65.000000
# 16-Sep                  153.800000
# 17-Apr                   80.975714
# 17-Aug                   98.994444
# 17-Dec                  123.115517
# 17-Feb                  152.000000
# 17-Jan                  139.000000
# 17-Jul                  124.023333
# 17-Jun                   72.122308
# 17-Mar                  111.500000
# 17-May                  117.875000
# 17-Nov                  120.614167
# 17-Oct                   67.128095
# 17-Sep                  199.287273
# 18-Apr                  100.053395
# 18-Aug                   69.952425
# 18-Dec                   96.820961
# 18-Feb                  126.775000
# 18-Jan                  160.642209
# 18-Jul                   99.332867
# 18-Jun                   75.849747
# 18-Mar                  137.800649
# 18-May                   99.380610
# 18-Nov                   61.646915
# 18-Oct                   82.041282
# 18-Sep                  102.719512
# 19-Apr                   57.028125
# 19-Aug                   68.948056
# 19-Dec                  111.379351
# 19-Feb                   72.103333
# 19-Jan                  367.552051
# 19-Jul                  107.154722
# 19-Jun                  125.617375
# 19-Mar                  102.198068
# 19-May                  104.002222
# 19-Nov                   42.797143
# 19-Oct                  117.598667
# 19-Sep                  109.861429
# 20-Apr                  264.737500
# 20-Aug                   62.422500
# 20-Dec                   81.913469
# 20-Feb                  135.595000
# 20-Jan                   78.934792
# 20-Jul                  297.600000
# 20-Jun                   85.594545
# 20-Mar                   70.155000
# 20-May                  323.500000
# 20-Nov                   83.285000
# 20-Oct                   57.637143
# 20-Sep                  100.835833
# 21-Aug                   51.600000
# 21-Dec                   64.648011
# 21-Feb                  103.881667
# 21-Jan                   59.250000
# 21-Jul                  117.702500
# 21-Jun                   81.465294
# 21-Mar                   80.915000
# 21-May                  109.001667
# 21-Nov                   56.513333
# 21-Oct                   48.000000
# 21-Sep                   64.893333
# 22-Dec                   62.100000
# 22-Jan                   65.166667
# 22-Jun                  107.224737
# 22-Mar                   49.000000
# 22-May                  225.500000
# 22-Nov                   78.370000
# Immediate Possession     98.921875
# Ready To Move           115.179137
# Name: price, dtype: float64

# %%
#drop insignificant features
df2=df1.drop(['area_type','availability','society','balcony'],axis=1)

# %%
df2.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
#check NaN values
df2.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
#check percentage 
round((100*df2.isnull().sum())/len(df2.index),2)
# Out:
# location      0.01
# size          0.12
# total_sqft    0.00
# bath          0.55
# price         0.00
# dtype: float64

# %%
#delete NaN Data

df3=df2.dropna()

# %%
df3.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
#check unique values of different types of bedrooms
df3['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
#apply split function to clear the data from size column
df3['BHK'] = df3['size'].apply(lambda x:x.split(' ')[0])

# %%
df3.head()
# Out:
#                    location       size total_sqft  bath   price BHK
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07   2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00   4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00   3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00   3
# 4                  Kothanur      2 BHK       1200   2.0   51.00   2

# %%
df3.drop(['size'],axis=1,inplace=True)

# %%
df3.head()
# Out:
#                    location total_sqft  bath   price BHK
# 0  Electronic City Phase II       1056   2.0   39.07   2
# 1          Chikka Tirupathi       2600   5.0  120.00   4
# 2               Uttarahalli       1440   2.0   62.00   3
# 3        Lingadheeranahalli       1521   3.0   95.00   3
# 4                  Kothanur       1200   2.0   51.00   2

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13246 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13246 non-null  object
#  1   total_sqft  13246 non-null  object
#  2   bath        13246 non-null  float64
#  3   price       13246 non-null  float64
#  4   BHK         13246 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 620.9+ KB

# %%
df3['BHK']=df3['BHK'].astype(int)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13246 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13246 non-null  object
#  1   total_sqft  13246 non-null  object
#  2   bath        13246 non-null  float64
#  3   price       13246 non-null  float64
#  4   BHK         13246 non-null  int32
# dtypes: float64(2), int32(1), object(2)
# memory usage: 569.2+ KB

# %%
df3['BHK'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18])

# %%
df3[df3['BHK']>=10]
# Out:
#                             location total_sqft  bath   price  BHK
# 459                     1 Giri Nagar       5000   9.0   360.0   11
# 1718       2Electronic City Phase II       8000  27.0   230.0   27
# 1735                   Kadarenahalli        750  10.0    90.0   10
# 1768              1 Ramamurthy Nagar       1200  11.0   170.0   11
# 1795                      SBM Colony       1660  10.0   475.0   10
# 3096            Jp nagar 8th Phase .      12000  12.0   525.0   10
# 3379                  1Hanuman Nagar       2000  16.0   490.0   19
# 3523                          Jigani       1200  10.0   105.0   10
# 3609   Koramangala Industrial Layout      10000  16.0   550.0   16
# 3853               1 Annasandrapalya       1200   6.0   150.0   11
# 4510                     Munnekollal       1200   7.0   240.0   10
# 4684                     Munnekollal       2400  40.0   660.0   43
# 4691           1st Block HRBR Layout       2416  10.0   600.0   10
# 4916                   1Channasandra       1250  15.0   125.0   14
# 6451                Kirloskar Layout       1200  10.0   190.0   10
# 6533                     Mysore Road       2232   6.0   300.0   12
# 7979                   1 Immadihalli       6000  12.0   150.0   11
# 8636                  Neeladri Nagar       4000  12.0   160.0   10
# 9511                     Munnekollal       1200   8.0   230.0   10
# 9769                   Maruthi Nagar       3300   9.0   450.0   10
# 9935                   1Hoysalanagar       5425  13.0   275.0   13
# 11128                         Jigani       1200  11.0   105.0   10
# 11142                    Munnekollal       7200  10.0   200.0   10
# 11327                         Kogilu       3280   9.0   450.0   10
# 11559                  1Kasavanhalli       1200  18.0   200.0   18
# 13067                 Defence Colony       7150  13.0  3600.0   10

# %%
df3['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
#custom function to convert string into float
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
#extract total_sqft data which are not converted into float - i.e. data with some mis-interpretations
df3[~df3['total_sqft'].apply(is_float)].head(20)
# Out:
#                    location      total_sqft  bath    price  BHK
# 30                Yelahanka     2100 - 2850   4.0  186.000    4
# 122                  Hebbal     3067 - 8156   4.0  477.000    4
# 137      8th Phase JP Nagar     1042 - 1105   2.0   54.005    2
# 165                Sarjapur     1145 - 1340   2.0   43.490    2
# 188                KR Puram     1015 - 1540   2.0   56.800    2
# 410                 Kengeri  34.46Sq. Meter   1.0   18.500    1
# 549             Hennur Road     1195 - 1440   2.0   63.770    2
# 648                 Arekere       4125Perch   9.0  265.000    9
# 661               Yelahanka     1120 - 1145   2.0   48.130    2
# 672            Bettahalsoor     3090 - 5002   4.0  445.000    4
# 772   Banashankari Stage VI     1160 - 1195   2.0   59.935    2
# 775            Basavanagara   1000Sq. Meter   2.0   93.000    1
# 850       Bannerghatta Road     1115 - 1130   2.0   58.935    2
# 872       Singapura Village   1100Sq. Yards   2.0   45.000    2
# 886              Chandapura       520 - 645   1.0   15.135    1
# 927             Thanisandra     1000 - 1285   2.0   43.415    2
# 959             Kammasandra       650 - 665   1.0   18.410    1
# 990                Sarjapur       633 - 666   1.0   17.535    1
# 1019         Marathi Layout       5.31Acres   1.0  110.000    1
# 1086             Narasapura         30Acres   2.0   29.500    2

# %%
#custom function to clean the sqft mis-interpreted data
def convert_sqft_to_num(x):
    lst_token = x.split('-')
    if len(lst_token) == 2:
        return (float(lst_token[0])+float(lst_token[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
#sanity check
convert_sqft_to_num('2100 - 2850')
# Out:
# 2475.0

# %%
#apply function on the total_sqft 
df3['total_sqft']=df3['total_sqft'].apply(convert_sqft_to_num)

# %%
df3.head()
# Out:
#                    location  total_sqft  bath   price  BHK
# 0  Electronic City Phase II      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4
# 2               Uttarahalli      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3
# 4                  Kothanur      1200.0   2.0   51.00    2

# %%
#check NaN data
df3['total_sqft'].isnull().sum()
# Out:
# 46

# %%
df3[df3['total_sqft'].isnull()]
# Out:
#                                            location  total_sqft  bath   price  \
# 410                                         Kengeri         NaN   1.0   18.50
# 648                                         Arekere         NaN   9.0  265.00
# 775                                    Basavanagara         NaN   2.0   93.00
# 872                               Singapura Village         NaN   2.0   45.00
# 1019                                 Marathi Layout         NaN   1.0  110.00
# 1086                                     Narasapura         NaN   2.0   29.50
# 1400                                     Chamrajpet         NaN   9.0  296.00
# 1712                               Singena Agrahara         NaN   3.0   95.00
# 1743                                      Hosa Road         NaN   3.0  115.00
# 1821                                       Sarjapur         NaN   3.0   76.00
# 2310                                     Whitefield         NaN   4.0  270.00
# 2881                             Volagerekallahalli         NaN   2.0   38.00
# 3228                                Dodda Banaswadi         NaN   5.0  140.00
# 3285                                     Whitefield         NaN   4.0  378.00
# 4113                                     BTM Layout         NaN   3.0   10.00
# 4293                              Bannerghatta Road         NaN   5.0  260.00
# 5453                                         Kannur         NaN   6.0   75.00
# 5537                                    Frazer Town         NaN   3.0  180.00
# 5631                                    Thanisandra         NaN   4.0  185.00
# 5668                                Judicial Layout         NaN   6.0  400.00
# 5708                                         Jigani         NaN   3.0  160.00
# 5976                             1st Phase JP Nagar         NaN   1.0   63.00
# 6268                                       Chickpet         NaN   2.0   48.00
# 6303                                       JP Nagar         NaN   3.0   69.34
# 6333                                      Harohalli         NaN   2.0  200.00
# 6552            5 Bedroom Farm House in Lakshmipura         NaN   6.0  550.00
# 6592                                  Langford Town         NaN   4.0  211.00
# 6953                                      Hosa Road         NaN   3.0  109.00
# 7001                               Thyagaraja Nagar         NaN   6.0  290.00
# 7248                                       Hulimavu         NaN   2.0   46.00
# 7334                                 Kanakpura Road         NaN   1.0  125.00
# 7520                                  Doddaballapur         NaN   2.0   48.00
# 7607                                   Bommenahalli         NaN   3.0  217.00
# 7726                                 Kanakpura Road         NaN   1.0  125.00
# 8273                                      V.V Puram         NaN   2.0  150.00
# 9423                               Ramamurthy Nagar         NaN   1.0   48.00
# 9519                                   Bommenahalli         NaN   3.0  232.00
# 9734                             Yelahanka New Town         NaN   2.0   18.00
# 10488  2 Bedroom Furnished Farm House in Kolar Road         NaN   2.0  200.00
# 10491                                      Rajapura         NaN   2.0   40.00
# 11320                                 Arishinakunte         NaN   1.0  170.00
# 11615                                         arudi         NaN   2.0   80.00
# 12186                            7th Phase JP Nagar         NaN   2.0   51.00
# 12252                                  Gowdanapalya         NaN   5.0   75.00
# 12560                                     Hosa Road         NaN   3.0  110.00
# 12652                              Billamaranahalli         NaN   2.0  150.00
#
#        BHK
# 410      1
# 648      9
# 775      1
# 872      2
# 1019     1
# 1086     2
# 1400     9
# 1712     3
# 1743     3
# 1821     3
# 2310     4
# 2881     2
# 3228     5
# 3285     4
# 4113     3
# 4293     4
# 5453     6
# 5537     3
# 5631     3
# 5668     5
# 5708     4
# 5976     1
# 6268     2
# 6303     3
# 6333     2
# 6552     5
# 6592     4
# 6953     3
# 7001     8
# 7248     2
# 7334     1
# 7520     3
# 7607     3
# 7726     1
# 8273     3
# 9423     1
# 9519     3
# 9734     1
# 10488    2
# 10491    2
# 11320    1
# 11615    3
# 12186    2
# 12252    5
# 12560    3
# 12652    2

# %% [markdown]
# ### Data Imputation with Iterative Imputer

# %%
#import required libraries from advanced imputation techniques

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imputer = IterativeImputer()

# %%
df3['total_sqft']=imputer.fit_transform(df3[['total_sqft']])

# %%
df3['total_sqft']=round(df3['total_sqft'])

# %%
df3['total_sqft'][410]
# Out:
# 1555.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13246 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13246 non-null  object
#  1   total_sqft  13246 non-null  float64
#  2   bath        13246 non-null  float64
#  3   price       13246 non-null  float64
#  4   BHK         13246 non-null  int32
# dtypes: float64(3), int32(1), object(1)
# memory usage: 1.2+ MB

# %%
df3.isnull().sum()
# Out:
# location      0
# total_sqft    0
# bath          0
# price         0
# BHK           0
# dtype: int64

# %% [markdown]
# ## Step 2: Feature Engineering

# %%
df3['price_per_sqft']=(df3['price']*100000)/df3['total_sqft']

# %%
df3.head()
# Out:
#                    location  total_sqft  bath   price  BHK  price_per_sqft
# 0  Electronic City Phase II      1056.0   2.0   39.07    2     3699.810606
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4     4615.384615
# 2               Uttarahalli      1440.0   2.0   62.00    3     4305.555556
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3     6245.890861
# 4                  Kothanur      1200.0   2.0   51.00    2     4250.000000

# %%
len(df3['location'].unique())
# Out:
# 1304

# %%
df3.location=df3.location.apply(lambda x:x.strip())

# %%
len(df3['location'].unique())
# Out:
# 1293

# %%
df3.location=df3.location.apply(lambda x:x.lower())

# %%
len(df3['location'].unique())
# Out:
# 1282

# %%
df3.head()
# Out:
#                    location  total_sqft  bath   price  BHK  price_per_sqft
# 0  electronic city phase ii      1056.0   2.0   39.07    2     3699.810606
# 1          chikka tirupathi      2600.0   5.0  120.00    4     4615.384615
# 2               uttarahalli      1440.0   2.0   62.00    3     4305.555556
# 3        lingadheeranahalli      1521.0   3.0   95.00    3     6245.890861
# 4                  kothanur      1200.0   2.0   51.00    2     4250.000000

# %%
df3.location = df3.location.apply(lambda x: x.strip())
location_stats = df3['location'].value_counts(ascending=False)
location_stats
# Out:
# whitefield                                        535
# sarjapur  road                                    392
# electronic city                                   304
# kanakpura road                                    266
# thanisandra                                       236
#                                                  ...
# karnataka shabarimala                               1
# narayanappa garden                                  1
# vinayaka layout                                     1
# ananthanagar phase 1,electronic city , phase 2      1
# gangondanahalli                                     1
# Name: location, Length: 1282, dtype: int64

# %%
len(location_stats[location_stats>10])
# Out:
# 241

# %%
#extract location data where total counts are less than or equal to 8 and named them 'Others'

location_stats_less_than_9 = location_stats[location_stats<=8]
location_stats_less_than_9
# Out:
# 1st block hrbr layout                             8
# nelamangala                                       8
# shikaripalya                                      8
# seetharampalya                                    8
# kanaka nagar                                      8
#                                                  ..
# karnataka shabarimala                             1
# narayanappa garden                                1
# vinayaka layout                                   1
# ananthanagar phase 1,electronic city , phase 2    1
# gangondanahalli                                   1
# Name: location, Length: 1006, dtype: int64

# %%
location_stats_less_than_9.unique()
# Out:
# array([8, 7, 6, 5, 4, 3, 2, 1], dtype=int64)

# %%
df3.location=df3.location.apply(lambda x:'other' if x in location_stats_less_than_9 else x)

# %%
len(df3.location.unique())
# Out:
# 277

# %%
df3.head(20)
# Out:
#                     location  total_sqft  bath   price  BHK  price_per_sqft
# 0   electronic city phase ii      1056.0   2.0   39.07    2     3699.810606
# 1           chikka tirupathi      2600.0   5.0  120.00    4     4615.384615
# 2                uttarahalli      1440.0   2.0   62.00    3     4305.555556
# 3         lingadheeranahalli      1521.0   3.0   95.00    3     6245.890861
# 4                   kothanur      1200.0   2.0   51.00    2     4250.000000
# 5                 whitefield      1170.0   2.0   38.00    2     3247.863248
# 6           old airport road      2732.0   4.0  204.00    4     7467.057101
# 7               rajaji nagar      3300.0   4.0  600.00    4    18181.818182
# 8               marathahalli      1310.0   3.0   63.25    3     4828.244275
# 9                      other      1020.0   6.0  370.00    6    36274.509804
# 10                whitefield      1800.0   2.0   70.00    3     3888.888889
# 11                whitefield      2785.0   5.0  295.00    4    10592.459605
# 12        7th phase jp nagar      1000.0   2.0   38.00    2     3800.000000
# 13                 gottigere      1100.0   2.0   40.00    2     3636.363636
# 14                  sarjapur      2250.0   3.0  148.00    3     6577.777778
# 15               mysore road      1175.0   2.0   73.50    2     6255.319149
# 16             bisuvanahalli      1180.0   3.0   48.00    3     4067.796610
# 17     raja rajeshwari nagar      1540.0   3.0   60.00    3     3896.103896
# 18                     other      2770.0   4.0  290.00    3    10469.314079
# 19                     other      1100.0   2.0   48.00    2     4363.636364

# %% [markdown]
# ## Step 3: Outliers Detection Using Business Rule

# %% [markdown]
# ### The Business rule will tell you that normally square ft per bedroom is 300 (i.e. 2 bhk apartment is minimum 600 sqft. If you have for example 400 sqft apartment with 2 bhk than that seems suspicious and can be removed as an outlier. We will remove such outliers by keeping our minimum thresold per bhk to be 300 sqft

# %% [markdown]
# #### Outlier Detection - 1

# %%
df3[df3['total_sqft']/df3['BHK']<300]
# Out:
#                       location  total_sqft  bath  price  BHK  price_per_sqft
# 9                        other      1020.0   6.0  370.0    6    36274.509804
# 45                  hsr layout       600.0   9.0  200.0    8    33333.333333
# 58               murugeshpalya      1407.0   4.0  150.0    6    10660.980810
# 68         devarachikkanahalli      1350.0   7.0   85.0    8     6296.296296
# 70                       other       500.0   3.0  100.0    3    20000.000000
# ...                        ...         ...   ...    ...  ...             ...
# 13277                    other      1400.0   7.0  218.0    7    15571.428571
# 13279  vishwanatha nagenahalli      1200.0   5.0  130.0    6    10833.333333
# 13281          margondanahalli      1375.0   5.0  125.0    5     9090.909091
# 13303           vidyaranyapura       774.0   5.0   70.0    5     9043.927649
# 13311         ramamurthy nagar      1500.0   9.0  250.0    7    16666.666667
#
# [748 rows x 6 columns]

# %%
df3.shape
# Out:
# (13246, 6)

# %%
df4 = df3[~(df3['total_sqft']/df3['BHK']<300)]

# %%
df4.shape
# Out:
# (12498, 6)

# %% [markdown]
# #### Outliers Detection - 2

# %% [markdown]
# #### By using describe method we can see that after the 99% of the data distribution the data grows exponentially which has to be managed

# %%
df4.price_per_sqft.describe([0.10,0.25,0.8,0.9,0.95,0.99])
# Out:
# count     12498.000000
# mean       6316.832988
# std        4184.051352
# min         267.829813
# 10%        3500.000000
# 25%        4210.526316
# 50%        5294.292025
# 80%        7474.184120
# 90%       10000.000000
# 95%       13392.857143
# 99%       21875.000000
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
#plot to visualize Price Per Sq. Ft. data distribution
ax=sb.distplot(df4['price_per_sqft'])
ax.set_xlabel('Price Per Square Feet',fontdict={'fontsize':16})
ax.set_title('Price Per Square Feet Data Distribution',fontdict={'fontsize':17})
# Out:
# Text(0.5,1,'Price Per Square Feet Data Distribution')

# %% [markdown]
# ### Cap Outliers with K-Sigma Technique

# %%
#custom function to cap outliers

def cap_outliers(df):
    df_out = pd.DataFrame() #empty data frame
    for key,sub_df in df.groupby('location'):
        mu=np.mean(sub_df.price_per_sqft)
        sigma=np.std(sub_df.price_per_sqft)
        reduced_df=sub_df[(sub_df.price_per_sqft>(mu-sigma)) & (sub_df.price_per_sqft<(mu+sigma))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=False)
    return df_out

# %%
df5=cap_outliers(df4)

# %%
df5.shape
# Out:
# (10240, 6)

# %%
df5.price_per_sqft.describe()
# Out:
# count    10240.000000
# mean      5680.538733
# std       2319.691529
# min       1250.000000
# 25%       4250.000000
# 50%       5178.142200
# 75%       6438.174665
# max      24509.803922
# Name: price_per_sqft, dtype: float64

# %%
ax=sb.distplot(df5['price_per_sqft'])
ax.set_xlabel('Price Per Square Feet',fontdict={'fontsize':16})
ax.set_title('Price Per Square Feet Data Distribution',fontdict={'fontsize':17})
# Out:
# Text(0.5,1,'Price Per Square Feet Data Distribution')

# %%
df5.head()
# Out:
#                  location  total_sqft  bath  price  BHK  price_per_sqft
# 210   1st block jayanagar      2850.0   4.0  428.0    4    15017.543860
# 848   1st block jayanagar      1630.0   3.0  194.0    3    11901.840491
# 2152  1st block jayanagar      1875.0   2.0  235.0    3    12533.333333
# 7138  1st block jayanagar      1200.0   2.0  130.0    3    10833.333333
# 7358  1st block jayanagar      1235.0   2.0  148.0    2    11983.805668

# %% [markdown]
# #### Outliers Detection - 3

# %%
df5.bath.unique()
# Out:
# array([ 4.,  3.,  2.,  5.,  1.,  8.,  9.,  6., 14.,  7., 12., 16., 13.])

# %%
df5[df5.bath>10]
# Out:
#             location  total_sqft  bath  price  BHK  price_per_sqft
# 1078   btm 1st stage      3300.0  14.0  500.0    9    15151.515152
# 8636  neeladri nagar      4000.0  12.0  160.0   10     4000.000000
# 3096           other     12000.0  12.0  525.0   10     4375.000000
# 3609           other     10000.0  16.0  550.0   16     5500.000000
# 7979           other      6000.0  12.0  150.0   11     2500.000000
# 9935           other      5425.0  13.0  275.0   13     5069.124424

# %% [markdown]
# #### It is unusual to have 2 more bathrooms than number of bedrooms in a home
#
# #### if you have 4 bedroom home and even if you have bathroom in all 4 rooms plus one guest bathroom, you will have total bath = total bed + 1 max. Anything above that is an outlier or a data error and can be removed

# %%
#check the total length of such bathrooms
len(df5[df5.bath>df5.BHK+1])
# Out:
# 93

# %%
df5.shape
# Out:
# (10240, 6)

# %%
# Drop such bathrooms and extract the remaining data

df6=df5[df5.bath<=df5.BHK+1]

# %%
df6.shape
# Out:
# (10147, 6)

# %%
df6.head()
# Out:
#                  location  total_sqft  bath  price  BHK  price_per_sqft
# 210   1st block jayanagar      2850.0   4.0  428.0    4    15017.543860
# 848   1st block jayanagar      1630.0   3.0  194.0    3    11901.840491
# 2152  1st block jayanagar      1875.0   2.0  235.0    3    12533.333333
# 7138  1st block jayanagar      1200.0   2.0  130.0    3    10833.333333
# 7358  1st block jayanagar      1235.0   2.0  148.0    2    11983.805668

# %%
df6.shape
# Out:
# (10147, 6)

# %% [markdown]
# #### Outliers Detection - 4
#
# #### It is unusual to have more prices of 1 or 2 BHK than 3 or more BHK in same location which has to be removed.

# %%
#custom function to create scatter plot

def scatter_plot(df,location,b1,b2):
    bhk2 = df[(df.location==location.lower()) & (df.BHK==b1)]
    bhk3 = df[(df.location==location.lower()) & (df.BHK==b2)]
    plt.scatter(bhk2.total_sqft,bhk2.price,color='blue',label=str(b1)+'BHK', s=50)
    plt.scatter(bhk3.total_sqft,bhk3.price,marker='+', color='green',label=str(b2)+'BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()

# %%
scatter_plot(df6,'rajaji nagar',2,3)

# %%
#custom function to remove such outliers

def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('BHK'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('BHK'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis=0)

# %%
df7 = remove_bhk_outliers(df6)

# %%
df7.shape
# Out:
# (7375, 6)

# %%
scatter_plot(df7,'rajaji nagar',2,3)

# %% [markdown]
# ## STEP - 4:  Dummy Encoding

# %%
location_df=pd.get_dummies(df7['location'])
location_df.head()
# Out:
#       1st block jayanagar  1st block koramangala  1st phase jp nagar  \
# 210                     1                      0                   0
# 848                     1                      0                   0
# 2152                    1                      0                   0
# 7138                    1                      0                   0
# 7358                    1                      0                   0
#
#       2nd phase jp nagar  2nd phase judicial layout  2nd stage nagarbhavi  \
# 210                    0                          0                     0
# 848                    0                          0                     0
# 2152                   0                          0                     0
# 7138                   0                          0                     0
# 7358                   0                          0                     0
#
#       4th block koramangala  5th block hbr layout  5th phase jp nagar  \
# 210                       0                     0                   0
# 848                       0                     0                   0
# 2152                      0                     0                   0
# 7138                      0                     0                   0
# 7358                      0                     0                   0
#
#       6th phase jp nagar  7th phase jp nagar  8th phase jp nagar  \
# 210                    0                   0                   0
# 848                    0                   0                   0
# 2152                   0                   0                   0
# 7138                   0                   0                   0
# 7358                   0                   0                   0
#
#       9th phase jp nagar  abbigere  aecs layout  akshaya nagar  ambalipura  \
# 210                    0         0            0              0           0
# 848                    0         0            0              0           0
# 2152                   0         0            0              0           0
# 7138                   0         0            0              0           0
# 7358                   0         0            0              0           0
#
#       ambedkar nagar  amruthahalli  anandapura  ananth nagar  anekal  \
# 210                0             0           0             0       0
# 848                0             0           0             0       0
# 2152               0             0           0             0       0
# 7138               0             0           0             0       0
# 7358               0             0           0             0       0
#
#       anjanapura  ardendale  arekere  attibele  b narayanapura  babusapalaya  \
# 210            0          0        0         0               0             0
# 848            0          0        0         0               0             0
# 2152           0          0        0         0               0             0
# 7138           0          0        0         0               0             0
# 7358           0          0        0         0               0             0
#
#       badavala nagar  balagere  banagiri nagar  banashankari  \
# 210                0         0               0             0
# 848                0         0               0             0
# 2152               0         0               0             0
# 7138               0         0               0             0
# 7358               0         0               0             0
#
#       banashankari stage ii  banashankari stage iii  banashankari stage v  \
# 210                       0                       0                     0
# 848                       0                       0                     0
# 2152                      0                       0                     0
# 7138                      0                       0                     0
# 7358                      0                       0                     0
#
#       banashankari stage vi  banaswadi  banjara layout  bannerghatta  \
# 210                       0          0               0             0
# 848                       0          0               0             0
# 2152                      0          0               0             0
# 7138                      0          0               0             0
# 7358                      0          0               0             0
#
#       bannerghatta road  basapura  basavangudi  basaveshwara nagar  \
# 210                   0         0            0                   0
# 848                   0         0            0                   0
# 2152                  0         0            0                   0
# 7138                  0         0            0                   0
# 7358                  0         0            0                   0
#
#       battarahalli  begur  begur road  bellandur  beml layout  benson town  \
# 210              0      0           0          0            0            0
# 848              0      0           0          0            0            0
# 2152             0      0           0          0            0            0
# 7138             0      0           0          0            0            0
# 7358             0      0           0          0            0            0
#
#       bharathi nagar  bhoganhalli  billekahalli  binny pete  bisuvanahalli  \
# 210                0            0             0           0              0
# 848                0            0             0           0              0
# 2152               0            0             0           0              0
# 7138               0            0             0           0              0
# 7358               0            0             0           0              0
#
#       bommanahalli  bommasandra  bommasandra industrial area  bommenahalli  \
# 210              0            0                            0             0
# 848              0            0                            0             0
# 2152             0            0                            0             0
# 7138             0            0                            0             0
# 7358             0            0                            0             0
#
#       brookefield  btm 1st stage  btm 2nd stage  btm layout  budigere  \
# 210             0              0              0           0         0
# 848             0              0              0           0         0
# 2152            0              0              0           0         0
# 7138            0              0              0           0         0
# 7358            0              0              0           0         0
#
#       chamrajpet  chandapura  chandra layout  channasandra  chennammana kere  \
# 210            0           0               0             0                 0
# 848            0           0               0             0                 0
# 2152           0           0               0             0                 0
# 7138           0           0               0             0                 0
# 7358           0           0               0             0                 0
#
#       chikka tirupathi  chikkabanavar  chikkalasandra  choodasandra  \
# 210                  0              0               0             0
# 848                  0              0               0             0
# 2152                 0              0               0             0
# 7138                 0              0               0             0
# 7358                 0              0               0             0
#
#       cooke town  cox town  cunningham road  cv raman nagar  dairy circle  \
# 210            0         0                0               0             0
# 848            0         0                0               0             0
# 2152           0         0                0               0             0
# 7138           0         0                0               0             0
# 7358           0         0                0               0             0
#
#       dasanapura  dasarahalli  devanahalli  devarachikkanahalli  \
# 210            0            0            0                    0
# 848            0            0            0                    0
# 2152           0            0            0                    0
# 7138           0            0            0                    0
# 7358           0            0            0                    0
#
#       dodda nekkundi  doddaballapur  doddakallasandra  doddathoguru  \
# 210                0              0                 0             0
# 848                0              0                 0             0
# 2152               0              0                 0             0
# 7138               0              0                 0             0
# 7358               0              0                 0             0
#
#       dodsworth layout  domlur  dommasandra  ejipura  electronic city  \
# 210                  0       0            0        0                0
# 848                  0       0            0        0                0
# 2152                 0       0            0        0                0
# 7138                 0       0            0        0                0
# 7358                 0       0            0        0                0
#
#       electronic city phase ii  electronics city phase 1  epip zone  \
# 210                          0                         0          0
# 848                          0                         0          0
# 2152                         0                         0          0
# 7138                         0                         0          0
# 7358                         0                         0          0
#
#       frazer town  ganga nagar  garudachar palya  giri nagar  gm palaya  \
# 210             0            0                 0           0          0
# 848             0            0                 0           0          0
# 2152            0            0                 0           0          0
# 7138            0            0                 0           0          0
# 7358            0            0                 0           0          0
#
#       gollahalli  gollarapalya hosahalli  gottigere  green glen layout  \
# 210            0                       0          0                  0
# 848            0                       0          0                  0
# 2152           0                       0          0                  0
# 7138           0                       0          0                  0
# 7358           0                       0          0                  0
#
#       gubbalala  gunjur  gunjur palya  hal 2nd stage  haralur road  harlur  \
# 210           0       0             0              0             0       0
# 848           0       0             0              0             0       0
# 2152          0       0             0              0             0       0
# 7138          0       0             0              0             0       0
# 7358          0       0             0              0             0       0
#
#       hbr layout  hebbal  hebbal kempapura  hegde nagar  hennur  hennur road  \
# 210            0       0                 0            0       0            0
# 848            0       0                 0            0       0            0
# 2152           0       0                 0            0       0            0
# 7138           0       0                 0            0       0            0
# 7358           0       0                 0            0       0            0
#
#       hoodi  horamavu agara  horamavu banaswadi  hormavu  hosa road  \
# 210       0               0                   0        0          0
# 848       0               0                   0        0          0
# 2152      0               0                   0        0          0
# 7138      0               0                   0        0          0
# 7358      0               0                   0        0          0
#
#       hosakerehalli  hoskote  hosur road  hrbr layout  hsr layout  hulimavu  \
# 210               0        0           0            0           0         0
# 848               0        0           0            0           0         0
# 2152              0        0           0            0           0         0
# 7138              0        0           0            0           0         0
# 7358              0        0           0            0           0         0
#
#       iblur village  indira nagar  isro layout  itpl  ittamadu  jakkur  \
# 210               0             0            0     0         0       0
# 848               0             0            0     0         0       0
# 2152              0             0            0     0         0       0
# 7138              0             0            0     0         0       0
# 7358              0             0            0     0         0       0
#
#       jakkur plantation  jalahalli  jalahalli east  jigani  jp nagar  \
# 210                   0          0               0       0         0
# 848                   0          0               0       0         0
# 2152                  0          0               0       0         0
# 7138                  0          0               0       0         0
# 7358                  0          0               0       0         0
#
#       judicial layout  kadubeesanahalli  kadugodi  kaggadasapura  kaggalipura  \
# 210                 0                 0         0              0            0
# 848                 0                 0         0              0            0
# 2152                0                 0         0              0            0
# 7138                0                 0         0              0            0
# 7358                0                 0         0              0            0
#
#       kaikondrahalli  kalena agrahara  kalkere  kalyan nagar  kamakshipalya  \
# 210                0                0        0             0              0
# 848                0                0        0             0              0
# 2152               0                0        0             0              0
# 7138               0                0        0             0              0
# 7358               0                0        0             0              0
#
#       kambipura  kammanahalli  kammasandra  kanakapura  kanakpura road  \
# 210           0             0            0           0               0
# 848           0             0            0           0               0
# 2152          0             0            0           0               0
# 7138          0             0            0           0               0
# 7358          0             0            0           0               0
#
#       kannamangala  karuna nagar  kasavanhalli  kasturi nagar  kathriguppe  \
# 210              0             0             0              0            0
# 848              0             0             0              0            0
# 2152             0             0             0              0            0
# 7138             0             0             0              0            0
# 7358             0             0             0              0            0
#
#       kaval byrasandra  kaverappa layout  kenchenahalli  kengeri  \
# 210                  0                 0              0        0
# 848                  0                 0              0        0
# 2152                 0                 0              0        0
# 7138                 0                 0              0        0
# 7358                 0                 0              0        0
#
#       kengeri satellite town  kereguddadahalli  kodichikkanahalli  \
# 210                        0                 0                  0
# 848                        0                 0                  0
# 2152                       0                 0                  0
# 7138                       0                 0                  0
# 7358                       0                 0                  0
#
#       kodigehaali  kodigehalli  kodihalli  kogilu  konanakunte  koramangala  \
# 210             0            0          0       0            0            0
# 848             0            0          0       0            0            0
# 2152            0            0          0       0            0            0
# 7138            0            0          0       0            0            0
# 7358            0            0          0       0            0            0
#
#       kothannur  kothanur  kr puram  kudlu  kudlu gate  kudlu main road  \
# 210           0         0         0      0           0                0
# 848           0         0         0      0           0                0
# 2152          0         0         0      0           0                0
# 7138          0         0         0      0           0                0
# 7358          0         0         0      0           0                0
#
#       kumaraswami layout  kundalahalli  laggere  lakshminarayana pura  \
# 210                    0             0        0                     0
# 848                    0             0        0                     0
# 2152                   0             0        0                     0
# 7138                   0             0        0                     0
# 7358                   0             0        0                     0
#
#       lb shastri nagar  lingadheeranahalli  lingarajapuram  magadi road  \
# 210                  0                   0               0            0
# 848                  0                   0               0            0
# 2152                 0                   0               0            0
# 7138                 0                   0               0            0
# 7358                 0                   0               0            0
#
#       mahadevpura  mahalakshmi layout  mallasandra  malleshpalya  \
# 210             0                   0            0             0
# 848             0                   0            0             0
# 2152            0                   0            0             0
# 7138            0                   0            0             0
# 7358            0                   0            0             0
#
#       malleshwaram  marathahalli  margondanahalli  marsur  mathikere  \
# 210              0             0                0       0          0
# 848              0             0                0       0          0
# 2152             0             0                0       0          0
# 7138             0             0                0       0          0
# 7358             0             0                0       0          0
#
#       medahalli  mico layout  munnekollal  murugeshpalya  mysore road  \
# 210           0            0            0              0            0
# 848           0            0            0              0            0
# 2152          0            0            0              0            0
# 7138          0            0            0              0            0
# 7358          0            0            0              0            0
#
#       nagadevanahalli  naganathapura  nagappa reddy layout  nagarbhavi  \
# 210                 0              0                     0           0
# 848                 0              0                     0           0
# 2152                0              0                     0           0
# 7138                0              0                     0           0
# 7358                0              0                     0           0
#
#       nagasandra  nagavara  nagavarapalya  narayanapura  neeladri nagar  \
# 210            0         0              0             0               0
# 848            0         0              0             0               0
# 2152           0         0              0             0               0
# 7138           0         0              0             0               0
# 7358           0         0              0             0               0
#
#       nehru nagar  ngr layout  nri layout  old airport road  old madras road  \
# 210             0           0           0                 0                0
# 848             0           0           0                 0                0
# 2152            0           0           0                 0                0
# 7138            0           0           0                 0                0
# 7358            0           0           0                 0                0
#
#       ombr layout  other  padmanabhanagar  pai layout  panathur  \
# 210             0      0                0           0         0
# 848             0      0                0           0         0
# 2152            0      0                0           0         0
# 7138            0      0                0           0         0
# 7358            0      0                0           0         0
#
#       parappana agrahara  pattandur agrahara  peenya  poorna pragna layout  \
# 210                    0                   0       0                     0
# 848                    0                   0       0                     0
# 2152                   0                   0       0                     0
# 7138                   0                   0       0                     0
# 7358                   0                   0       0                     0
#
#       prithvi layout  r.t. nagar  rachenahalli  raja rajeshwari nagar  \
# 210                0           0             0                      0
# 848                0           0             0                      0
# 2152               0           0             0                      0
# 7138               0           0             0                      0
# 7358               0           0             0                      0
#
#       rajaji nagar  rajiv nagar  ramagondanahalli  ramamurthy nagar  \
# 210              0            0                 0                 0
# 848              0            0                 0                 0
# 2152             0            0                 0                 0
# 7138             0            0                 0                 0
# 7358             0            0                 0                 0
#
#       rayasandra  richmond town  sadashiva nagar  sahakara nagar  \
# 210            0              0                0               0
# 848            0              0                0               0
# 2152           0              0                0               0
# 7138           0              0                0               0
# 7358           0              0                0               0
#
#       sanjay nagar  sarakki nagar  sarjapur  sarjapur  road  \
# 210              0              0         0               0
# 848              0              0         0               0
# 2152             0              0         0               0
# 7138             0              0         0               0
# 7358             0              0         0               0
#
#       sarjapura - attibele road  sector 1 hsr layout  sector 2 hsr layout  \
# 210                           0                    0                    0
# 848                           0                    0                    0
# 2152                          0                    0                    0
# 7138                          0                    0                    0
# 7358                          0                    0                    0
#
#       sector 7 hsr layout  seegehalli  shampura  shivaji nagar  singasandra  \
# 210                     0           0         0              0            0
# 848                     0           0         0              0            0
# 2152                    0           0         0              0            0
# 7138                    0           0         0              0            0
# 7358                    0           0         0              0            0
#
#       somasundara palya  sompura  sonnenahalli  subramanyapura  sultan palaya  \
# 210                   0        0             0               0              0
# 848                   0        0             0               0              0
# 2152                  0        0             0               0              0
# 7138                  0        0             0               0              0
# 7358                  0        0             0               0              0
#
#       talaghattapura  tc palaya  thanisandra  thigalarapalya  thubarahalli  \
# 210                0          0            0               0             0
# 848                0          0            0               0             0
# 2152               0          0            0               0             0
# 7138               0          0            0               0             0
# 7358               0          0            0               0             0
#
#       thyagaraja nagar  tindlu  tumkur road  ulsoor  uttarahalli  varthur  \
# 210                  0       0            0       0            0        0
# 848                  0       0            0       0            0        0
# 2152                 0       0            0       0            0        0
# 7138                 0       0            0       0            0        0
# 7358                 0       0            0       0            0        0
#
#       varthur road  vasanthapura  vidyaranyapura  vignana nagar  vijayanagar  \
# 210              0             0               0              0            0
# 848              0             0               0              0            0
# 2152             0             0               0              0            0
# 7138             0             0               0              0            0
# 7358             0             0               0              0            0
#
#       vishveshwarya layout  vishwanatha nagenahalli  vishwapriya layout  \
# 210                      0                        0                   0
# 848                      0                        0                   0
# 2152                     0                        0                   0
# 7138                     0                        0                   0
# 7358                     0                        0                   0
#
#       vittasandra  volagerekallahalli  whitefield  yelachenahalli  yelahanka  \
# 210             0                   0           0               0          0
# 848             0                   0           0               0          0
# 2152            0                   0           0               0          0
# 7138            0                   0           0               0          0
# 7358            0                   0           0               0          0
#
#       yelahanka new town  yelenahalli  yemlur  yeshwanthpur
# 210                    0            0       0             0
# 848                    0            0       0             0
# 2152                   0            0       0             0
# 7138                   0            0       0             0
# 7358                   0            0       0             0

# %%
df8=pd.concat([df7,location_df.drop('other',axis=1),],axis=1)

# %%
df8.head()
# Out:
#                  location  total_sqft  bath  price  BHK  price_per_sqft  \
# 210   1st block jayanagar      2850.0   4.0  428.0    4    15017.543860
# 848   1st block jayanagar      1630.0   3.0  194.0    3    11901.840491
# 2152  1st block jayanagar      1875.0   2.0  235.0    3    12533.333333
# 7138  1st block jayanagar      1200.0   2.0  130.0    3    10833.333333
# 7358  1st block jayanagar      1235.0   2.0  148.0    2    11983.805668
#
#       1st block jayanagar  1st block koramangala  1st phase jp nagar  \
# 210                     1                      0                   0
# 848                     1                      0                   0
# 2152                    1                      0                   0
# 7138                    1                      0                   0
# 7358                    1                      0                   0
#
#       2nd phase jp nagar  2nd phase judicial layout  2nd stage nagarbhavi  \
# 210                    0                          0                     0
# 848                    0                          0                     0
# 2152                   0                          0                     0
# 7138                   0                          0                     0
# 7358                   0                          0                     0
#
#       4th block koramangala  5th block hbr layout  5th phase jp nagar  \
# 210                       0                     0                   0
# 848                       0                     0                   0
# 2152                      0                     0                   0
# 7138                      0                     0                   0
# 7358                      0                     0                   0
#
#       6th phase jp nagar  7th phase jp nagar  8th phase jp nagar  \
# 210                    0                   0                   0
# 848                    0                   0                   0
# 2152                   0                   0                   0
# 7138                   0                   0                   0
# 7358                   0                   0                   0
#
#       9th phase jp nagar  abbigere  aecs layout  akshaya nagar  ambalipura  \
# 210                    0         0            0              0           0
# 848                    0         0            0              0           0
# 2152                   0         0            0              0           0
# 7138                   0         0            0              0           0
# 7358                   0         0            0              0           0
#
#       ambedkar nagar  amruthahalli  anandapura  ananth nagar  anekal  \
# 210                0             0           0             0       0
# 848                0             0           0             0       0
# 2152               0             0           0             0       0
# 7138               0             0           0             0       0
# 7358               0             0           0             0       0
#
#       anjanapura  ardendale  arekere  attibele  b narayanapura  babusapalaya  \
# 210            0          0        0         0               0             0
# 848            0          0        0         0               0             0
# 2152           0          0        0         0               0             0
# 7138           0          0        0         0               0             0
# 7358           0          0        0         0               0             0
#
#       badavala nagar  balagere  banagiri nagar  banashankari  \
# 210                0         0               0             0
# 848                0         0               0             0
# 2152               0         0               0             0
# 7138               0         0               0             0
# 7358               0         0               0             0
#
#       banashankari stage ii  banashankari stage iii  banashankari stage v  \
# 210                       0                       0                     0
# 848                       0                       0                     0
# 2152                      0                       0                     0
# 7138                      0                       0                     0
# 7358                      0                       0                     0
#
#       banashankari stage vi  banaswadi  banjara layout  bannerghatta  \
# 210                       0          0               0             0
# 848                       0          0               0             0
# 2152                      0          0               0             0
# 7138                      0          0               0             0
# 7358                      0          0               0             0
#
#       bannerghatta road  basapura  basavangudi  basaveshwara nagar  \
# 210                   0         0            0                   0
# 848                   0         0            0                   0
# 2152                  0         0            0                   0
# 7138                  0         0            0                   0
# 7358                  0         0            0                   0
#
#       battarahalli  begur  begur road  bellandur  beml layout  benson town  \
# 210              0      0           0          0            0            0
# 848              0      0           0          0            0            0
# 2152             0      0           0          0            0            0
# 7138             0      0           0          0            0            0
# 7358             0      0           0          0            0            0
#
#       bharathi nagar  bhoganhalli  billekahalli  binny pete  bisuvanahalli  \
# 210                0            0             0           0              0
# 848                0            0             0           0              0
# 2152               0            0             0           0              0
# 7138               0            0             0           0              0
# 7358               0            0             0           0              0
#
#       bommanahalli  bommasandra  bommasandra industrial area  bommenahalli  \
# 210              0            0                            0             0
# 848              0            0                            0             0
# 2152             0            0                            0             0
# 7138             0            0                            0             0
# 7358             0            0                            0             0
#
#       brookefield  btm 1st stage  btm 2nd stage  btm layout  budigere  \
# 210             0              0              0           0         0
# 848             0              0              0           0         0
# 2152            0              0              0           0         0
# 7138            0              0              0           0         0
# 7358            0              0              0           0         0
#
#       chamrajpet  chandapura  chandra layout  channasandra  chennammana kere  \
# 210            0           0               0             0                 0
# 848            0           0               0             0                 0
# 2152           0           0               0             0                 0
# 7138           0           0               0             0                 0
# 7358           0           0               0             0                 0
#
#       chikka tirupathi  chikkabanavar  chikkalasandra  choodasandra  \
# 210                  0              0               0             0
# 848                  0              0               0             0
# 2152                 0              0               0             0
# 7138                 0              0               0             0
# 7358                 0              0               0             0
#
#       cooke town  cox town  cunningham road  cv raman nagar  dairy circle  \
# 210            0         0                0               0             0
# 848            0         0                0               0             0
# 2152           0         0                0               0             0
# 7138           0         0                0               0             0
# 7358           0         0                0               0             0
#
#       dasanapura  dasarahalli  devanahalli  devarachikkanahalli  \
# 210            0            0            0                    0
# 848            0            0            0                    0
# 2152           0            0            0                    0
# 7138           0            0            0                    0
# 7358           0            0            0                    0
#
#       dodda nekkundi  doddaballapur  doddakallasandra  doddathoguru  \
# 210                0              0                 0             0
# 848                0              0                 0             0
# 2152               0              0                 0             0
# 7138               0              0                 0             0
# 7358               0              0                 0             0
#
#       dodsworth layout  domlur  dommasandra  ejipura  electronic city  \
# 210                  0       0            0        0                0
# 848                  0       0            0        0                0
# 2152                 0       0            0        0                0
# 7138                 0       0            0        0                0
# 7358                 0       0            0        0                0
#
#       electronic city phase ii  electronics city phase 1  epip zone  \
# 210                          0                         0          0
# 848                          0                         0          0
# 2152                         0                         0          0
# 7138                         0                         0          0
# 7358                         0                         0          0
#
#       frazer town  ganga nagar  garudachar palya  giri nagar  gm palaya  \
# 210             0            0                 0           0          0
# 848             0            0                 0           0          0
# 2152            0            0                 0           0          0
# 7138            0            0                 0           0          0
# 7358            0            0                 0           0          0
#
#       gollahalli  gollarapalya hosahalli  gottigere  green glen layout  \
# 210            0                       0          0                  0
# 848            0                       0          0                  0
# 2152           0                       0          0                  0
# 7138           0                       0          0                  0
# 7358           0                       0          0                  0
#
#       gubbalala  gunjur  gunjur palya  hal 2nd stage  haralur road  harlur  \
# 210           0       0             0              0             0       0
# 848           0       0             0              0             0       0
# 2152          0       0             0              0             0       0
# 7138          0       0             0              0             0       0
# 7358          0       0             0              0             0       0
#
#       hbr layout  hebbal  hebbal kempapura  hegde nagar  hennur  hennur road  \
# 210            0       0                 0            0       0            0
# 848            0       0                 0            0       0            0
# 2152           0       0                 0            0       0            0
# 7138           0       0                 0            0       0            0
# 7358           0       0                 0            0       0            0
#
#       hoodi  horamavu agara  horamavu banaswadi  hormavu  hosa road  \
# 210       0               0                   0        0          0
# 848       0               0                   0        0          0
# 2152      0               0                   0        0          0
# 7138      0               0                   0        0          0
# 7358      0               0                   0        0          0
#
#       hosakerehalli  hoskote  hosur road  hrbr layout  hsr layout  hulimavu  \
# 210               0        0           0            0           0         0
# 848               0        0           0            0           0         0
# 2152              0        0           0            0           0         0
# 7138              0        0           0            0           0         0
# 7358              0        0           0            0           0         0
#
#       iblur village  indira nagar  isro layout  itpl  ittamadu  jakkur  \
# 210               0             0            0     0         0       0
# 848               0             0            0     0         0       0
# 2152              0             0            0     0         0       0
# 7138              0             0            0     0         0       0
# 7358              0             0            0     0         0       0
#
#       jakkur plantation  jalahalli  jalahalli east  jigani  jp nagar  \
# 210                   0          0               0       0         0
# 848                   0          0               0       0         0
# 2152                  0          0               0       0         0
# 7138                  0          0               0       0         0
# 7358                  0          0               0       0         0
#
#       judicial layout  kadubeesanahalli  kadugodi  kaggadasapura  kaggalipura  \
# 210                 0                 0         0              0            0
# 848                 0                 0         0              0            0
# 2152                0                 0         0              0            0
# 7138                0                 0         0              0            0
# 7358                0                 0         0              0            0
#
#       kaikondrahalli  kalena agrahara  kalkere  kalyan nagar  kamakshipalya  \
# 210                0                0        0             0              0
# 848                0                0        0             0              0
# 2152               0                0        0             0              0
# 7138               0                0        0             0              0
# 7358               0                0        0             0              0
#
#       kambipura  kammanahalli  kammasandra  kanakapura  kanakpura road  \
# 210           0             0            0           0               0
# 848           0             0            0           0               0
# 2152          0             0            0           0               0
# 7138          0             0            0           0               0
# 7358          0             0            0           0               0
#
#       kannamangala  karuna nagar  kasavanhalli  kasturi nagar  kathriguppe  \
# 210              0             0             0              0            0
# 848              0             0             0              0            0
# 2152             0             0             0              0            0
# 7138             0             0             0              0            0
# 7358             0             0             0              0            0
#
#       kaval byrasandra  kaverappa layout  kenchenahalli  kengeri  \
# 210                  0                 0              0        0
# 848                  0                 0              0        0
# 2152                 0                 0              0        0
# 7138                 0                 0              0        0
# 7358                 0                 0              0        0
#
#       kengeri satellite town  kereguddadahalli  kodichikkanahalli  \
# 210                        0                 0                  0
# 848                        0                 0                  0
# 2152                       0                 0                  0
# 7138                       0                 0                  0
# 7358                       0                 0                  0
#
#       kodigehaali  kodigehalli  kodihalli  kogilu  konanakunte  koramangala  \
# 210             0            0          0       0            0            0
# 848             0            0          0       0            0            0
# 2152            0            0          0       0            0            0
# 7138            0            0          0       0            0            0
# 7358            0            0          0       0            0            0
#
#       kothannur  kothanur  kr puram  kudlu  kudlu gate  kudlu main road  \
# 210           0         0         0      0           0                0
# 848           0         0         0      0           0                0
# 2152          0         0         0      0           0                0
# 7138          0         0         0      0           0                0
# 7358          0         0         0      0           0                0
#
#       kumaraswami layout  kundalahalli  laggere  lakshminarayana pura  \
# 210                    0             0        0                     0
# 848                    0             0        0                     0
# 2152                   0             0        0                     0
# 7138                   0             0        0                     0
# 7358                   0             0        0                     0
#
#       lb shastri nagar  lingadheeranahalli  lingarajapuram  magadi road  \
# 210                  0                   0               0            0
# 848                  0                   0               0            0
# 2152                 0                   0               0            0
# 7138                 0                   0               0            0
# 7358                 0                   0               0            0
#
#       mahadevpura  mahalakshmi layout  mallasandra  malleshpalya  \
# 210             0                   0            0             0
# 848             0                   0            0             0
# 2152            0                   0            0             0
# 7138            0                   0            0             0
# 7358            0                   0            0             0
#
#       malleshwaram  marathahalli  margondanahalli  marsur  mathikere  \
# 210              0             0                0       0          0
# 848              0             0                0       0          0
# 2152             0             0                0       0          0
# 7138             0             0                0       0          0
# 7358             0             0                0       0          0
#
#       medahalli  mico layout  munnekollal  murugeshpalya  mysore road  \
# 210           0            0            0              0            0
# 848           0            0            0              0            0
# 2152          0            0            0              0            0
# 7138          0            0            0              0            0
# 7358          0            0            0              0            0
#
#       nagadevanahalli  naganathapura  nagappa reddy layout  nagarbhavi  \
# 210                 0              0                     0           0
# 848                 0              0                     0           0
# 2152                0              0                     0           0
# 7138                0              0                     0           0
# 7358                0              0                     0           0
#
#       nagasandra  nagavara  nagavarapalya  narayanapura  neeladri nagar  \
# 210            0         0              0             0               0
# 848            0         0              0             0               0
# 2152           0         0              0             0               0
# 7138           0         0              0             0               0
# 7358           0         0              0             0               0
#
#       nehru nagar  ngr layout  nri layout  old airport road  old madras road  \
# 210             0           0           0                 0                0
# 848             0           0           0                 0                0
# 2152            0           0           0                 0                0
# 7138            0           0           0                 0                0
# 7358            0           0           0                 0                0
#
#       ombr layout  padmanabhanagar  pai layout  panathur  parappana agrahara  \
# 210             0                0           0         0                   0
# 848             0                0           0         0                   0
# 2152            0                0           0         0                   0
# 7138            0                0           0         0                   0
# 7358            0                0           0         0                   0
#
#       pattandur agrahara  peenya  poorna pragna layout  prithvi layout  \
# 210                    0       0                     0               0
# 848                    0       0                     0               0
# 2152                   0       0                     0               0
# 7138                   0       0                     0               0
# 7358                   0       0                     0               0
#
#       r.t. nagar  rachenahalli  raja rajeshwari nagar  rajaji nagar  \
# 210            0             0                      0             0
# 848            0             0                      0             0
# 2152           0             0                      0             0
# 7138           0             0                      0             0
# 7358           0             0                      0             0
#
#       rajiv nagar  ramagondanahalli  ramamurthy nagar  rayasandra  \
# 210             0                 0                 0           0
# 848             0                 0                 0           0
# 2152            0                 0                 0           0
# 7138            0                 0                 0           0
# 7358            0                 0                 0           0
#
#       richmond town  sadashiva nagar  sahakara nagar  sanjay nagar  \
# 210               0                0               0             0
# 848               0                0               0             0
# 2152              0                0               0             0
# 7138              0                0               0             0
# 7358              0                0               0             0
#
#       sarakki nagar  sarjapur  sarjapur  road  sarjapura - attibele road  \
# 210               0         0               0                          0
# 848               0         0               0                          0
# 2152              0         0               0                          0
# 7138              0         0               0                          0
# 7358              0         0               0                          0
#
#       sector 1 hsr layout  sector 2 hsr layout  sector 7 hsr layout  \
# 210                     0                    0                    0
# 848                     0                    0                    0
# 2152                    0                    0                    0
# 7138                    0                    0                    0
# 7358                    0                    0                    0
#
#       seegehalli  shampura  shivaji nagar  singasandra  somasundara palya  \
# 210            0         0              0            0                  0
# 848            0         0              0            0                  0
# 2152           0         0              0            0                  0
# 7138           0         0              0            0                  0
# 7358           0         0              0            0                  0
#
#       sompura  sonnenahalli  subramanyapura  sultan palaya  talaghattapura  \
# 210         0             0               0              0               0
# 848         0             0               0              0               0
# 2152        0             0               0              0               0
# 7138        0             0               0              0               0
# 7358        0             0               0              0               0
#
#       tc palaya  thanisandra  thigalarapalya  thubarahalli  thyagaraja nagar  \
# 210           0            0               0             0                 0
# 848           0            0               0             0                 0
# 2152          0            0               0             0                 0
# 7138          0            0               0             0                 0
# 7358          0            0               0             0                 0
#
#       tindlu  tumkur road  ulsoor  uttarahalli  varthur  varthur road  \
# 210        0            0       0            0        0             0
# 848        0            0       0            0        0             0
# 2152       0            0       0            0        0             0
# 7138       0            0       0            0        0             0
# 7358       0            0       0            0        0             0
#
#       vasanthapura  vidyaranyapura  vignana nagar  vijayanagar  \
# 210              0               0              0            0
# 848              0               0              0            0
# 2152             0               0              0            0
# 7138             0               0              0            0
# 7358             0               0              0            0
#
#       vishveshwarya layout  vishwanatha nagenahalli  vishwapriya layout  \
# 210                      0                        0                   0
# 848                      0                        0                   0
# 2152                     0                        0                   0
# 7138                     0                        0                   0
# 7358                     0                        0                   0
#
#       vittasandra  volagerekallahalli  whitefield  yelachenahalli  yelahanka  \
# 210             0                   0           0               0          0
# 848             0                   0           0               0          0
# 2152            0                   0           0               0          0
# 7138            0                   0           0               0          0
# 7358            0                   0           0               0          0
#
#       yelahanka new town  yelenahalli  yemlur  yeshwanthpur
# 210                    0            0       0             0
# 848                    0            0       0             0
# 2152                   0            0       0             0
# 7138                   0            0       0             0
# 7358                   0            0       0             0

# %%
df8.drop(['location','price_per_sqft'],axis=1,inplace=True)

# %%
df8.shape
# Out:
# (7375, 280)

# %% [markdown]
# ## STEP - 5:  Train - Test Split

# %%
#import necessary packages
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#Create X and y
y=df8.pop('price')
X = df8

# %%
y.head()
# Out:
# 210     428.0
# 848     194.0
# 2152    235.0
# 7138    130.0
# 7358    148.0
# Name: price, dtype: float64

# %%
X.head()
# Out:
#       total_sqft  bath  BHK  1st block jayanagar  1st block koramangala  \
# 210       2850.0   4.0    4                    1                      0
# 848       1630.0   3.0    3                    1                      0
# 2152      1875.0   2.0    3                    1                      0
# 7138      1200.0   2.0    3                    1                      0
# 7358      1235.0   2.0    2                    1                      0
#
#       1st phase jp nagar  2nd phase jp nagar  2nd phase judicial layout  \
# 210                    0                   0                          0
# 848                    0                   0                          0
# 2152                   0                   0                          0
# 7138                   0                   0                          0
# 7358                   0                   0                          0
#
#       2nd stage nagarbhavi  4th block koramangala  5th block hbr layout  \
# 210                      0                      0                     0
# 848                      0                      0                     0
# 2152                     0                      0                     0
# 7138                     0                      0                     0
# 7358                     0                      0                     0
#
#       5th phase jp nagar  6th phase jp nagar  7th phase jp nagar  \
# 210                    0                   0                   0
# 848                    0                   0                   0
# 2152                   0                   0                   0
# 7138                   0                   0                   0
# 7358                   0                   0                   0
#
#       8th phase jp nagar  9th phase jp nagar  abbigere  aecs layout  \
# 210                    0                   0         0            0
# 848                    0                   0         0            0
# 2152                   0                   0         0            0
# 7138                   0                   0         0            0
# 7358                   0                   0         0            0
#
#       akshaya nagar  ambalipura  ambedkar nagar  amruthahalli  anandapura  \
# 210               0           0               0             0           0
# 848               0           0               0             0           0
# 2152              0           0               0             0           0
# 7138              0           0               0             0           0
# 7358              0           0               0             0           0
#
#       ananth nagar  anekal  anjanapura  ardendale  arekere  attibele  \
# 210              0       0           0          0        0         0
# 848              0       0           0          0        0         0
# 2152             0       0           0          0        0         0
# 7138             0       0           0          0        0         0
# 7358             0       0           0          0        0         0
#
#       b narayanapura  babusapalaya  badavala nagar  balagere  banagiri nagar  \
# 210                0             0               0         0               0
# 848                0             0               0         0               0
# 2152               0             0               0         0               0
# 7138               0             0               0         0               0
# 7358               0             0               0         0               0
#
#       banashankari  banashankari stage ii  banashankari stage iii  \
# 210              0                      0                       0
# 848              0                      0                       0
# 2152             0                      0                       0
# 7138             0                      0                       0
# 7358             0                      0                       0
#
#       banashankari stage v  banashankari stage vi  banaswadi  banjara layout  \
# 210                      0                      0          0               0
# 848                      0                      0          0               0
# 2152                     0                      0          0               0
# 7138                     0                      0          0               0
# 7358                     0                      0          0               0
#
#       bannerghatta  bannerghatta road  basapura  basavangudi  \
# 210              0                  0         0            0
# 848              0                  0         0            0
# 2152             0                  0         0            0
# 7138             0                  0         0            0
# 7358             0                  0         0            0
#
#       basaveshwara nagar  battarahalli  begur  begur road  bellandur  \
# 210                    0             0      0           0          0
# 848                    0             0      0           0          0
# 2152                   0             0      0           0          0
# 7138                   0             0      0           0          0
# 7358                   0             0      0           0          0
#
#       beml layout  benson town  bharathi nagar  bhoganhalli  billekahalli  \
# 210             0            0               0            0             0
# 848             0            0               0            0             0
# 2152            0            0               0            0             0
# 7138            0            0               0            0             0
# 7358            0            0               0            0             0
#
#       binny pete  bisuvanahalli  bommanahalli  bommasandra  \
# 210            0              0             0            0
# 848            0              0             0            0
# 2152           0              0             0            0
# 7138           0              0             0            0
# 7358           0              0             0            0
#
#       bommasandra industrial area  bommenahalli  brookefield  btm 1st stage  \
# 210                             0             0            0              0
# 848                             0             0            0              0
# 2152                            0             0            0              0
# 7138                            0             0            0              0
# 7358                            0             0            0              0
#
#       btm 2nd stage  btm layout  budigere  chamrajpet  chandapura  \
# 210               0           0         0           0           0
# 848               0           0         0           0           0
# 2152              0           0         0           0           0
# 7138              0           0         0           0           0
# 7358              0           0         0           0           0
#
#       chandra layout  channasandra  chennammana kere  chikka tirupathi  \
# 210                0             0                 0                 0
# 848                0             0                 0                 0
# 2152               0             0                 0                 0
# 7138               0             0                 0                 0
# 7358               0             0                 0                 0
#
#       chikkabanavar  chikkalasandra  choodasandra  cooke town  cox town  \
# 210               0               0             0           0         0
# 848               0               0             0           0         0
# 2152              0               0             0           0         0
# 7138              0               0             0           0         0
# 7358              0               0             0           0         0
#
#       cunningham road  cv raman nagar  dairy circle  dasanapura  dasarahalli  \
# 210                 0               0             0           0            0
# 848                 0               0             0           0            0
# 2152                0               0             0           0            0
# 7138                0               0             0           0            0
# 7358                0               0             0           0            0
#
#       devanahalli  devarachikkanahalli  dodda nekkundi  doddaballapur  \
# 210             0                    0               0              0
# 848             0                    0               0              0
# 2152            0                    0               0              0
# 7138            0                    0               0              0
# 7358            0                    0               0              0
#
#       doddakallasandra  doddathoguru  dodsworth layout  domlur  dommasandra  \
# 210                  0             0                 0       0            0
# 848                  0             0                 0       0            0
# 2152                 0             0                 0       0            0
# 7138                 0             0                 0       0            0
# 7358                 0             0                 0       0            0
#
#       ejipura  electronic city  electronic city phase ii  \
# 210         0                0                         0
# 848         0                0                         0
# 2152        0                0                         0
# 7138        0                0                         0
# 7358        0                0                         0
#
#       electronics city phase 1  epip zone  frazer town  ganga nagar  \
# 210                          0          0            0            0
# 848                          0          0            0            0
# 2152                         0          0            0            0
# 7138                         0          0            0            0
# 7358                         0          0            0            0
#
#       garudachar palya  giri nagar  gm palaya  gollahalli  \
# 210                  0           0          0           0
# 848                  0           0          0           0
# 2152                 0           0          0           0
# 7138                 0           0          0           0
# 7358                 0           0          0           0
#
#       gollarapalya hosahalli  gottigere  green glen layout  gubbalala  gunjur  \
# 210                        0          0                  0          0       0
# 848                        0          0                  0          0       0
# 2152                       0          0                  0          0       0
# 7138                       0          0                  0          0       0
# 7358                       0          0                  0          0       0
#
#       gunjur palya  hal 2nd stage  haralur road  harlur  hbr layout  hebbal  \
# 210              0              0             0       0           0       0
# 848              0              0             0       0           0       0
# 2152             0              0             0       0           0       0
# 7138             0              0             0       0           0       0
# 7358             0              0             0       0           0       0
#
#       hebbal kempapura  hegde nagar  hennur  hennur road  hoodi  \
# 210                  0            0       0            0      0
# 848                  0            0       0            0      0
# 2152                 0            0       0            0      0
# 7138                 0            0       0            0      0
# 7358                 0            0       0            0      0
#
#       horamavu agara  horamavu banaswadi  hormavu  hosa road  hosakerehalli  \
# 210                0                   0        0          0              0
# 848                0                   0        0          0              0
# 2152               0                   0        0          0              0
# 7138               0                   0        0          0              0
# 7358               0                   0        0          0              0
#
#       hoskote  hosur road  hrbr layout  hsr layout  hulimavu  iblur village  \
# 210         0           0            0           0         0              0
# 848         0           0            0           0         0              0
# 2152        0           0            0           0         0              0
# 7138        0           0            0           0         0              0
# 7358        0           0            0           0         0              0
#
#       indira nagar  isro layout  itpl  ittamadu  jakkur  jakkur plantation  \
# 210              0            0     0         0       0                  0
# 848              0            0     0         0       0                  0
# 2152             0            0     0         0       0                  0
# 7138             0            0     0         0       0                  0
# 7358             0            0     0         0       0                  0
#
#       jalahalli  jalahalli east  jigani  jp nagar  judicial layout  \
# 210           0               0       0         0                0
# 848           0               0       0         0                0
# 2152          0               0       0         0                0
# 7138          0               0       0         0                0
# 7358          0               0       0         0                0
#
#       kadubeesanahalli  kadugodi  kaggadasapura  kaggalipura  kaikondrahalli  \
# 210                  0         0              0            0               0
# 848                  0         0              0            0               0
# 2152                 0         0              0            0               0
# 7138                 0         0              0            0               0
# 7358                 0         0              0            0               0
#
#       kalena agrahara  kalkere  kalyan nagar  kamakshipalya  kambipura  \
# 210                 0        0             0              0          0
# 848                 0        0             0              0          0
# 2152                0        0             0              0          0
# 7138                0        0             0              0          0
# 7358                0        0             0              0          0
#
#       kammanahalli  kammasandra  kanakapura  kanakpura road  kannamangala  \
# 210              0            0           0               0             0
# 848              0            0           0               0             0
# 2152             0            0           0               0             0
# 7138             0            0           0               0             0
# 7358             0            0           0               0             0
#
#       karuna nagar  kasavanhalli  kasturi nagar  kathriguppe  \
# 210              0             0              0            0
# 848              0             0              0            0
# 2152             0             0              0            0
# 7138             0             0              0            0
# 7358             0             0              0            0
#
#       kaval byrasandra  kaverappa layout  kenchenahalli  kengeri  \
# 210                  0                 0              0        0
# 848                  0                 0              0        0
# 2152                 0                 0              0        0
# 7138                 0                 0              0        0
# 7358                 0                 0              0        0
#
#       kengeri satellite town  kereguddadahalli  kodichikkanahalli  \
# 210                        0                 0                  0
# 848                        0                 0                  0
# 2152                       0                 0                  0
# 7138                       0                 0                  0
# 7358                       0                 0                  0
#
#       kodigehaali  kodigehalli  kodihalli  kogilu  konanakunte  koramangala  \
# 210             0            0          0       0            0            0
# 848             0            0          0       0            0            0
# 2152            0            0          0       0            0            0
# 7138            0            0          0       0            0            0
# 7358            0            0          0       0            0            0
#
#       kothannur  kothanur  kr puram  kudlu  kudlu gate  kudlu main road  \
# 210           0         0         0      0           0                0
# 848           0         0         0      0           0                0
# 2152          0         0         0      0           0                0
# 7138          0         0         0      0           0                0
# 7358          0         0         0      0           0                0
#
#       kumaraswami layout  kundalahalli  laggere  lakshminarayana pura  \
# 210                    0             0        0                     0
# 848                    0             0        0                     0
# 2152                   0             0        0                     0
# 7138                   0             0        0                     0
# 7358                   0             0        0                     0
#
#       lb shastri nagar  lingadheeranahalli  lingarajapuram  magadi road  \
# 210                  0                   0               0            0
# 848                  0                   0               0            0
# 2152                 0                   0               0            0
# 7138                 0                   0               0            0
# 7358                 0                   0               0            0
#
#       mahadevpura  mahalakshmi layout  mallasandra  malleshpalya  \
# 210             0                   0            0             0
# 848             0                   0            0             0
# 2152            0                   0            0             0
# 7138            0                   0            0             0
# 7358            0                   0            0             0
#
#       malleshwaram  marathahalli  margondanahalli  marsur  mathikere  \
# 210              0             0                0       0          0
# 848              0             0                0       0          0
# 2152             0             0                0       0          0
# 7138             0             0                0       0          0
# 7358             0             0                0       0          0
#
#       medahalli  mico layout  munnekollal  murugeshpalya  mysore road  \
# 210           0            0            0              0            0
# 848           0            0            0              0            0
# 2152          0            0            0              0            0
# 7138          0            0            0              0            0
# 7358          0            0            0              0            0
#
#       nagadevanahalli  naganathapura  nagappa reddy layout  nagarbhavi  \
# 210                 0              0                     0           0
# 848                 0              0                     0           0
# 2152                0              0                     0           0
# 7138                0              0                     0           0
# 7358                0              0                     0           0
#
#       nagasandra  nagavara  nagavarapalya  narayanapura  neeladri nagar  \
# 210            0         0              0             0               0
# 848            0         0              0             0               0
# 2152           0         0              0             0               0
# 7138           0         0              0             0               0
# 7358           0         0              0             0               0
#
#       nehru nagar  ngr layout  nri layout  old airport road  old madras road  \
# 210             0           0           0                 0                0
# 848             0           0           0                 0                0
# 2152            0           0           0                 0                0
# 7138            0           0           0                 0                0
# 7358            0           0           0                 0                0
#
#       ombr layout  padmanabhanagar  pai layout  panathur  parappana agrahara  \
# 210             0                0           0         0                   0
# 848             0                0           0         0                   0
# 2152            0                0           0         0                   0
# 7138            0                0           0         0                   0
# 7358            0                0           0         0                   0
#
#       pattandur agrahara  peenya  poorna pragna layout  prithvi layout  \
# 210                    0       0                     0               0
# 848                    0       0                     0               0
# 2152                   0       0                     0               0
# 7138                   0       0                     0               0
# 7358                   0       0                     0               0
#
#       r.t. nagar  rachenahalli  raja rajeshwari nagar  rajaji nagar  \
# 210            0             0                      0             0
# 848            0             0                      0             0
# 2152           0             0                      0             0
# 7138           0             0                      0             0
# 7358           0             0                      0             0
#
#       rajiv nagar  ramagondanahalli  ramamurthy nagar  rayasandra  \
# 210             0                 0                 0           0
# 848             0                 0                 0           0
# 2152            0                 0                 0           0
# 7138            0                 0                 0           0
# 7358            0                 0                 0           0
#
#       richmond town  sadashiva nagar  sahakara nagar  sanjay nagar  \
# 210               0                0               0             0
# 848               0                0               0             0
# 2152              0                0               0             0
# 7138              0                0               0             0
# 7358              0                0               0             0
#
#       sarakki nagar  sarjapur  sarjapur  road  sarjapura - attibele road  \
# 210               0         0               0                          0
# 848               0         0               0                          0
# 2152              0         0               0                          0
# 7138              0         0               0                          0
# 7358              0         0               0                          0
#
#       sector 1 hsr layout  sector 2 hsr layout  sector 7 hsr layout  \
# 210                     0                    0                    0
# 848                     0                    0                    0
# 2152                    0                    0                    0
# 7138                    0                    0                    0
# 7358                    0                    0                    0
#
#       seegehalli  shampura  shivaji nagar  singasandra  somasundara palya  \
# 210            0         0              0            0                  0
# 848            0         0              0            0                  0
# 2152           0         0              0            0                  0
# 7138           0         0              0            0                  0
# 7358           0         0              0            0                  0
#
#       sompura  sonnenahalli  subramanyapura  sultan palaya  talaghattapura  \
# 210         0             0               0              0               0
# 848         0             0               0              0               0
# 2152        0             0               0              0               0
# 7138        0             0               0              0               0
# 7358        0             0               0              0               0
#
#       tc palaya  thanisandra  thigalarapalya  thubarahalli  thyagaraja nagar  \
# 210           0            0               0             0                 0
# 848           0            0               0             0                 0
# 2152          0            0               0             0                 0
# 7138          0            0               0             0                 0
# 7358          0            0               0             0                 0
#
#       tindlu  tumkur road  ulsoor  uttarahalli  varthur  varthur road  \
# 210        0            0       0            0        0             0
# 848        0            0       0            0        0             0
# 2152       0            0       0            0        0             0
# 7138       0            0       0            0        0             0
# 7358       0            0       0            0        0             0
#
#       vasanthapura  vidyaranyapura  vignana nagar  vijayanagar  \
# 210              0               0              0            0
# 848              0               0              0            0
# 2152             0               0              0            0
# 7138             0               0              0            0
# 7358             0               0              0            0
#
#       vishveshwarya layout  vishwanatha nagenahalli  vishwapriya layout  \
# 210                      0                        0                   0
# 848                      0                        0                   0
# 2152                     0                        0                   0
# 7138                     0                        0                   0
# 7358                     0                        0                   0
#
#       vittasandra  volagerekallahalli  whitefield  yelachenahalli  yelahanka  \
# 210             0                   0           0               0          0
# 848             0                   0           0               0          0
# 2152            0                   0           0               0          0
# 7138            0                   0           0               0          0
# 7358            0                   0           0               0          0
#
#       yelahanka new town  yelenahalli  yemlur  yeshwanthpur
# 210                    0            0       0             0
# 848                    0            0       0             0
# 2152                   0            0       0             0
# 7138                   0            0       0             0
# 7358                   0            0       0             0

# %%
#reset index

X=X.reset_index()
X.drop(['index'],axis=1,inplace=True)

# %%
#split the data in train and test dataset

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %% [markdown]
# ## STEP - 6: Feature Scaling

# %%
#import necessary libraries
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)

# %% [markdown]
# ## STEP - 7: Model Building

# %%
#Build a linear Regression model
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=model.predict(X_train)

# %%
# evaluate the model by using r2 score

r2_score(y_train,y_pred)
# Out:
# 0.8721980012127748

# %% [markdown]
# ## STEP - 8: Residual Analysis

# %%
# Residual Analysis to prove Linear Regression Assumptions
res = y_train - y_pred
ax = sb.distplot(res,color='green')
ax.set_xlabel('Residuals',fontdict={'fontsize':16})
ax.set_title('Residuals Analysis',fontdict={'fontsize':17})
# Out:
# Text(0.5,1,'Residuals Analysis')

# %% [markdown]
# ## STEP - 9: Test the model

# %%
X_test=scaler.transform(X_test)

# %%
y_pred_2=model.predict(X_test)

# %%
# Evaluate the test data

r2_score(y_test,y_pred_2)
# Out:
# 0.8625053671560746

# %%
# Again residual Analysis
res2 = y_test - y_pred_2
ax = sb.distplot(res2,color='red')
ax.set_xlabel('Residuals',fontdict={'fontsize':16})
ax.set_title('Test Residuals Analysis',fontdict={'fontsize':17})
# Out:
# Text(0.5,1,'Test Residuals Analysis')

# %% [markdown]
# ### Model Evaluation

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred_2)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0,0.5,'y_pred')

# %% [markdown]
# ## Single Price Prediction

# %%
#custom function to predict the price

def predict_price(location,sqft,bath,bhk):    
    try:         
        location=location.lower()
        loc_index = np.where(X.columns==location)[0][0] #6
        x = np.zeros(len(X.columns))
        x[0] = sqft
        x[1] = bath
        x[2] = bhk
        if loc_index >= 0:
            x[loc_index] = 1
        x_trans=scaler.transform([x])
        return model.predict(x_trans)[0]
    except:
        return 'invalid location'

# %%
predict_price('1st phase jp nagar',1000,2,2)
# Out:
# 85.59522967445358

# %%
predict_price('gdgkdjgkdjgkdgkjdhg',2000,3,3)
# Out:
# 'invalid location'

# %% [markdown]
# ### Import file into pickle

# %%
import pickle,json

# %%
# scaling data saved in pickle file on a disk

with open('bengaluru_house_price_prediction_scale.pickle',"wb") as f:
    pickle.dump(scaler,f)
    print("scaling file saved")
# Out:
# scaling file saved

# %%
# model saved in pickle file on a disk 

with open('bengaluru_house_price_prediction.pickle',"wb") as f:
    pickle.dump(model,f)
    print("model file saved")
# Out:
# model file saved

# %%
# creating json file 

columns = {   #this is json object
    'all_columns':[col for col in X.columns] #this is json array
}

with open('all_columns.json','w') as f:
    json.dump(columns,f)
